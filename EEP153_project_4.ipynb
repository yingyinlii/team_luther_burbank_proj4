# %% [markdown]
# # __Group Project 4 - Team Luther Burbank__
# <br>
#
#
# ### <span style = "color:dark">__Team Members: Yingyin Li, William Lee, Kanay Mathur, Kevin Kim, Qianhao (Harry) Zhong__
# <br>
#
#
#
# ## **1. Project Topic & Goal:**
#
# __We intend to analyze the food demand system in Panama, evaluate the nutritional composition of various food items, and assess the nutritional sufficiency of households in Panama. Our objectives include establishing criteria for essential nutrients, identifying prevalent nutritional deficiencies, and examining challenges faced by Panamanian households in meeting recommended dietary intakes.__
#
# > * Preliminary findings suggest that a significant portion of Panamanian households exhibit deficiencies in essential nutrients such as vitamin A, vitamin C, and fiber, with a notable percentage failing to meet recommended daily intake levels.
# > * Furthermore, while carbohydrate consumption generally aligns with recommendations for most households, there exists a subset that surpasses the recommended intake. This excess intake may predispose individuals to issues such as caloric surplus, elevated blood glucose levels, and nutrient imbalances, warranting further investigation and intervention.

# %% [markdown]
# <br>
#
#
# ## **2. Policy Exploration:**
#
# __Our policies are designed to elevate the nutritional quality of Panamanian households by targeting the attainment of vitamin and fiber sufficiency in two-thirds of the population. To realize these objectives, our strategies encompass:__
#
# >* Implementing food stamp programs or subsidies aimed at reducing the cost of high-vitamin and high-fiber foods in the market, particularly fruits and vegetables.
# >* Providing subsidies to local restaurants contingent upon the adaptation of their menus to include a minimum of 70% items rich in vitamins and fiber.
# >* Introducing tax incentives for farmers engaged in the production of fiber-rich foods, thereby encouraging the cultivation and availability of such dietary essentials.

# %% [markdown]
# <br>
#
# ## **3. Data(set) Description:**
#
# > ####  __Main DataSet - [Panama Dataset](https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=2085637103):__ This spreadsheet encompasses all the data we aim to manipulate. It contained subsheets titled <span style = "color:#0ED4F3"> <u>Household Characteristics, FCT (Food Composition Table), Food Expenditures, RDI (Recommended Dietary Intake), and Food Prices</span>.
# > * #### __Subsheet 1 - [Household Characteristics](https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=1095902684):__ This subsheet presents household data collected from multiple provinces in Panama, including Herrera, Bocas Del Toro, Chiriquí, Colón, and Panamá, spanning the years 1997 to 2008. It offers a detailed breakdown of household composition by gender and age group across these provinces, providing insight into the demographic diversity within the surveyed regions over the specified timeframe.
# > * #### __Subsheet 2 - [FCT](https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=881999882):__ This sheet provides a comprehensive overview of the nutritional content of different foods per 100 grams of edible portion. Each row corresponds to a specific food item, while the columns contain data regarding its water content, energy value, macronutrient composition, and other nutritional components.
# > * #### __Subsheet 3 - [Food Expenditures](https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=2085637103):__ This dataset is structured as a multi-indexed dataset, featuring information on food expenditure across diverse households. The indexing incorporates three levels: year, region, and household identifier. This hierarchical organization facilitates systematic analysis, enabling examination of fluctuations in food expenditure over time, disparities across geographical regions, and variations among individual households.
# > * #### __Subsheet 4 - [Food Prices](https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=1029038038):__ This spreadsheet seems to comprise a collection of food items alongside their prices and measurements across different regions and time periods in Panama. Each row likely represents a unique food item and its corresponding measurement, while each column denotes various regions or time periods. The values within each cell likely indicate the corresponding price and unit of measurement for the specified region or period, providing a comprehensive overview of food prices and availability over time and across different geographical areas within Panama.
# > * #### __Subsheet 5 - [RDI](https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=342562131):__ This sheet outlines recommended daily intake levels of various nutrients for different age and gender groups. It spans from infancy to older adulthood, detailing values for nutrients such as Energy, Protein, Fiber, Folate, Calcium, and more. Each demographic group, categorized by age and gender, has specific recommended intake levels for optimal nutrition.
#
# <br>
#
# ## **4. Project Deliverables:**

# %% [markdown]
# ### *Packages Import*:

# %%
# The lengthy output has been hidden
# Try to re-run this code if you encounter "ERROR: pip's dependency resolver does not currently take into account all the packages that are installed."
# !pip install -r requirements.txt -q
# !pip install CFEDemands --upgrade --pre -q
# !pip install eep153_tools --upgrade -q

# %%
from cfe.estimation import drop_columns_wo_covariance
from eep153_tools.sheets import read_sheets
import matplotlib.pyplot as plt
from cfe import Regression
from cfe import regression as rgsn
import numpy as np
import pandas as pd
import cfe
import warnings

# %% [markdown]
# <br>
#
# ### *DATA Import, DATA Cleaning*:

# %%
InputFiles = {"Expenditures": ("1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE", "Food Expenditures"),
              'Prices':('1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE','Food Prices'),
              'HH Characteristics':('1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE','Household Characteristics'),
              'FCT':('1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE','FCT'),
              'RDI':('1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE','RDI')}

# %%
def get_clean_sheet(key,sheet=None):

    df = read_sheets(key,sheet=sheet)
    
    df.columns = [c.strip() for c in df.columns.tolist()]

    df = df.loc[:,~df.columns.duplicated(keep='first')]   

    df = df.drop([col for col in df.columns if col.startswith('Unnamed')], axis=1)

    df = df.loc[~df.index.duplicated(), :]

    return df

# %%
################# Get expenditures #################
Expenditures = get_clean_sheet(InputFiles['Expenditures'][0],
                    sheet=InputFiles['Expenditures'][1])

if 'm' not in Expenditures.columns:  # If Expenditures doesn't include column "m", create one manually.
    Expenditures['m'] = 1
    
Expenditures = Expenditures.set_index(['i','t','m'])
Expenditures.columns.name = 'j'

Expenditures = Expenditures.apply(lambda x: pd.to_numeric(x,errors='coerce'))
Expenditures = Expenditures.replace(0,np.nan)  # Convert all zeros to NaN


################# Get HH characteristics #################
HH_characteristics = get_clean_sheet(InputFiles['HH Characteristics'][0],
                    sheet=InputFiles['HH Characteristics'][1])

if 'm' not in HH_characteristics.columns:
    HH_characteristics['m'] = 1

HH_characteristics = HH_characteristics.set_index(['i','t','m'])
HH_characteristics.columns.name = 'k'  # Assign a overarching column name to coloumn indexes

HH_characteristics = HH_characteristics.apply(lambda x: pd.to_numeric(x,errors='coerce'))



################# Get prices #################
price_url = 'https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=2085637103'

prices = read_sheets(price_url, sheet='Food Prices', nheaders=2)
prices.columns.names = ['t', 'm']  # Assign two column names to two headers
# since there are multiple prices for food in various sizes, we choose to use average price 
prices.groupby(level='j').mean()
prices=prices.transpose()
if 'm' not in prices.columns:  # Supply "market" indicator if missing
    prices['m'] = 1  
prices = prices.apply(lambda x: pd.to_numeric(x,errors='coerce'))
prices = prices.replace(0,np.nan)



################# fct #################
fct = get_clean_sheet(InputFiles['FCT'][0],
                    sheet=InputFiles['FCT'][1])

fct = fct.set_index('j')
fct.columns.name = 'n'
fct = fct.apply(lambda x: pd.to_numeric(x,errors='coerce'))



################# RDI, if available (consider using US) #################
rdi = get_clean_sheet(InputFiles['RDI'][0],
                    sheet=InputFiles['RDI'][1])

rdi = rdi.set_index('n')
rdi.columns.name = 'k'
new_column_names = [
"Females 00-03", "Males 00-03", "Females 04-08", "Males 04-08", "Females 09-13", "Males 09-13", 
    "Females 14-18", "Males 14-18",  "Females 19-30", "Males 19-30", "Females 31-50", "Males 31-50",  "Females 51-99", "Males 51-99"]
column_name_mapping = {old: new for old, new in zip(rdi.columns, new_column_names)}
rdi.rename(columns=column_name_mapping, inplace=True)

### From above, we get "Expenditures", "HH_characteristics", "prices", "fct", "rdi"

# %% [markdown]
# <br>
#
# ### *Cleaned DataFrame Display*:

# %%
Expenditures.head()
# Out:
# j                       Aceite Vegetal  Aguacates  Ahí Verde  Ajo  \
# i        t    m
# 19971000 1997 Chíriqui             6.0        NaN        0.5  NaN
# 19971001 1997 Chíriqui             NaN        NaN        NaN  NaN
# 19971002 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971003 1997 Chíriqui             3.5        NaN        NaN  NaN
# 19971005 1997 Chíriqui             3.7        NaN        NaN  NaN
#
# j                       Alimento Infantil  Apio  Arroz  Arvejas  Azúcar  \
# i        t    m
# 19971000 1997 Chíriqui                2.7   0.3   7.25      NaN     1.6
# 19971001 1997 Chíriqui                NaN   NaN   4.80      NaN     NaN
# 19971002 1997 Chíriqui                NaN   NaN   6.00      NaN     2.0
# 19971003 1997 Chíriqui                NaN   NaN    NaN      NaN     NaN
# 19971005 1997 Chíriqui                NaN   NaN    NaN      NaN     4.5
#
# j                       Café Y Té  ...  Sodas, Refrescos Y Jugos  \
# i        t    m                    ...
# 19971000 1997 Chíriqui        NaN  ...                       8.0
# 19971001 1997 Chíriqui        1.4  ...                       1.5
# 19971002 1997 Chíriqui        3.6  ...                       NaN
# 19971003 1997 Chíriqui        NaN  ...                       NaN
# 19971005 1997 Chíriqui        1.5  ...                       NaN
#
# j                       Sopa Enlatada  Tercer otro  Tomate  Viscera De Res  \
# i        t    m
# 19971000 1997 Chíriqui            0.7          NaN     NaN             NaN
# 19971001 1997 Chíriqui            NaN          NaN     0.3             NaN
# 19971002 1997 Chíriqui            3.5          NaN     NaN             NaN
# 19971003 1997 Chíriqui            NaN          NaN     NaN             NaN
# 19971005 1997 Chíriqui            0.7          NaN     NaN             NaN
#
# j                       Visceras De Pollo O Gallina  Yuca  Zanahoria  \
# i        t    m
# 19971000 1997 Chíriqui                          NaN   NaN        0.8
# 19971001 1997 Chíriqui                          NaN   NaN        NaN
# 19971002 1997 Chíriqui                          NaN   NaN        NaN
# 19971003 1997 Chíriqui                          NaN   NaN        NaN
# 19971005 1997 Chíriqui                          NaN   1.0        NaN
#
# j                       Zapallo / Chayote  Ñame
# i        t    m
# 19971000 1997 Chíriqui                NaN   0.4
# 19971001 1997 Chíriqui                NaN   NaN
# 19971002 1997 Chíriqui                2.0   NaN
# 19971003 1997 Chíriqui                NaN   NaN
# 19971005 1997 Chíriqui                NaN   NaN
#
# [5 rows x 84 columns]

# %%
HH_characteristics.head()
# Out:
# k                            women  boys  men  girls  Males 00-03  \
# i       t    m
# 1997125 1997 Herrera             1     1    1      0            0
# 1997160 1997 Herrera             2     0    1      0            0
# 1997170 1997 Bocas Del Toro      1     3    1      4            1
# 1997177 1997 Bocas Del Toro      4     9    1      5            2
# 1997178 1997 Bocas Del Toro      2     1    2      2            0
#
# k                            Females 00-03  Males 04-08  Females 04-08  \
# i       t    m
# 1997125 1997 Herrera                     0            0              0
# 1997160 1997 Herrera                     0            0              0
# 1997170 1997 Bocas Del Toro              2            1              0
# 1997177 1997 Bocas Del Toro              1            4              1
# 1997178 1997 Bocas Del Toro              0            0              1
#
# k                            Males 09-13  Females 09-13  Males 14-18  \
# i       t    m
# 1997125 1997 Herrera                   1              0            0
# 1997160 1997 Herrera                   0              0            0
# 1997170 1997 Bocas Del Toro            0              1            1
# 1997177 1997 Bocas Del Toro            1              3            2
# 1997178 1997 Bocas Del Toro            1              0            0
#
# k                            Females 14-18  Males 19-30  Females 19-30  \
# i       t    m
# 1997125 1997 Herrera                     0            0              0
# 1997160 1997 Herrera                     0            0              0
# 1997170 1997 Bocas Del Toro              1            0              0
# 1997177 1997 Bocas Del Toro              0            0              2
# 1997178 1997 Bocas Del Toro              1            2              0
#
# k                            Males 31-50  Females 31-50  Males 51-99  \
# i       t    m
# 1997125 1997 Herrera                   0              1            1
# 1997160 1997 Herrera                   0              1            1
# 1997170 1997 Bocas Del Toro            0              1            1
# 1997177 1997 Bocas Del Toro            0              2            1
# 1997178 1997 Bocas Del Toro            0              1            0
#
# k                            Females 51-99  log HSize
# i       t    m
# 1997125 1997 Herrera                     0   1.098612
# 1997160 1997 Herrera                     1   1.098612
# 1997170 1997 Bocas Del Toro              0   2.197225
# 1997177 1997 Bocas Del Toro              0   2.944439
# 1997178 1997 Bocas Del Toro              1   1.945910

# %%
prices.head()
# Out:
# j                   Aceite Vegetal                                            \
# u                       1/2 gallon  None bottle    can gallon gram large bay
# t    m
# 1997 Bocas Del Toro          3.225   NaN   1.20  2.975   6.70  NaN     1.500
#      Chíriqui                3.250  0.10   1.35    NaN   5.95  NaN     1.350
#      Coclé                   2.990  0.10   1.30    NaN   5.90  NaN     1.375
#      Colón                   3.250  0.10   1.34    NaN   5.75  NaN       NaN
#      Darién                  3.200  0.25   1.40    NaN   4.85  NaN     1.525
#
# j                                                ... Zapallo / Chayote  \
# u                   liter medium bar milliliter  ...              unit
# t    m                                           ...
# 1997 Bocas Del Toro   NaN      1.050        NaN  ...              0.10
#      Chíriqui         NaN      1.325        NaN  ...              0.10
#      Coclé            NaN      1.275        NaN  ...              0.15
#      Colón            NaN      0.850        NaN  ...              0.25
#      Darién           NaN      1.400        NaN  ...               NaN
#
# j                                    Ñame                                 \
# u                       value bag or sack gram ounce package pound  unit
# t    m
# 1997 Bocas Del Toro       NaN         3.6  NaN   NaN     NaN  0.40   NaN
#      Chíriqui        0.084416         NaN  NaN   NaN     NaN  0.40  0.15
#      Coclé           0.201299         NaN  NaN   NaN     NaN  0.50  0.50
#      Colón           0.045455         NaN  NaN   NaN     NaN  0.40  0.60
#      Darién               NaN         NaN  NaN   NaN     NaN  0.15   NaN
#
# j                              m
# u                       value
# t    m
# 1997 Bocas Del Toro       NaN  1
#      Chíriqui        0.038961  1
#      Coclé                NaN  1
#      Colón           0.064935  1
#      Darién               NaN  1
#
# [5 rows x 691 columns]

# %%
fct.head()
# Out:
# n                   Agua  Energía  Proteina  Grasa Total  Carbo-hidratos  \
# j
# Aceite Vegetal      0.00      884      0.00       100.00            0.00
# Aguacates          73.23      160      2.00        14.66            8.53
# Ahí Verde          93.89       20      0.86         0.17            3.64
# Ajo                63.80      134      5.30         0.20           29.30
# Alimento Infantil   3.00      510     12.50        27.00           54.30
#
# n                  Fibra Diet. total  Ceniza  Calcio  Fosforo  Hierro  ...  \
# j                                                                      ...
# Aceite Vegetal                   0.0    0.00       0        0    0.00  ...
# Aguacates                        6.7    1.58      12       52    0.55  ...
# Ahí Verde                        1.7    0.43      10       20    0.34  ...
# Ajo                              0.0    1.40      38      134    1.40  ...
# Alimento Infantil                0.0    3.20     530      420    9.00  ...
#
# n                  Colesterol  Potasio  Sodio  Zinc  Magnesio  Vit. B6  \
# j
# Aceite Vegetal              0        0      0  0.00         0     0.00
# Aguacates                   0      485      7  0.64        29     0.26
# Ahí Verde                   0      175      3  0.13        10     0.22
# Ajo                         0      529     19  1.00         0     0.00
# Alimento Infantil           0      600    180  6.00        55     0.30
#
# n                  Vit. B12  Ac. Fólico  Folato Equiv. FD  Fracción Comestible
# j
# Aceite Vegetal          0.0           0                 0                 1.00
# Aguacates               0.0           0                81                 0.74
# Ahí Verde               0.0           0                11                 0.82
# Ajo                     0.0           3                 0                 0.94
# Alimento Infantil       1.5          80               136                 1.00
#
# [5 rows x 28 columns]

# %%
rdi.head()
# Out:
# k        Females 00-03  Males 00-03  Females 04-08  Males 04-08  \
# n
# Energy          1000.0       1000.0         1200.0       1400.0
# Protein           13.0         13.0           19.0         19.0
# Fiber             14.0         14.0           16.8         19.6
# Folate           150.0        150.0          200.0        200.0
# Calcium          700.0        700.0         1000.0       1000.0
#
# k        Females 09-13  Males 09-13  Females 14-18  Males 14-18  \
# n
# Energy          1600.0       1800.0         1800.0       2200.0
# Protein           34.0         34.0           46.0         52.0
# Fiber             22.4         25.2           25.2         30.8
# Folate           300.0        300.0          400.0        400.0
# Calcium         1300.0       1300.0         1300.0       1300.0
#
# k        Females 19-30  Males 19-30  Females 31-50  Males 31-50  \
# n
# Energy          2000.0       2400.0         1800.0       2200.0
# Protein           46.0         56.0           46.0         56.0
# Fiber             28.0         33.6           25.2         30.8
# Folate           400.0        400.0          400.0        400.0
# Calcium         1000.0       1000.0         1000.0       1000.0
#
# k        Females 51-99  Males 51-99
# n
# Energy          1600.0       2000.0
# Protein           46.0         56.0
# Fiber             22.4         28.0
# Folate           400.0        400.0
# Calcium         1200.0       1000.0

# %% [markdown]
# <br>
#
#
# ## __[A] Estimate Demand System__
#
# * ### *Main Demand System Regression Equation:*
#
# <br>
#
# $$
#       y^j_{i} = A^j(p) + \gamma_j'd_i + \beta_j w_i + \zeta^j_i.
# $$
# <br>
#
# > $y_{i}^j$ : *__Logarithmic expenditures on food $j$ by household $i$ at a particular time.__*
# >
# > $A^j(p)$ : *__Sub-function of price $p$ of food $j$. It captures the demand elasticity of food $j$ .__*
# >
# > $\gamma_j'd_i$ : *__Variable $d_i$ represents household characteristics. The coefficient $\gamma_j'$ signifies how food expenditure changes in response to variations in household composition.__*
# >
# > $\beta_j w_i$ : *__Variable $w_i$ represents household wealth. The coefficient $\beta_j$ indicates how changes in household wealth affect food expenditure.__*
# >
# > $\zeta^j_i$ : *__The error term represents all sources of variation in the dependent variable ($y_{i}^j$) that are not explained by the independent variables included in regression function.__*

# %% [markdown]
# * ### *To enhance the accuracy of our demand prediction model given limited data, we broke down the main equation into a sub-equation comprising two available variables. We then conducted regression analysis, correlating food expenditure with household composition (characteristics) and food prices:*
#
# <br>
#
# $$
#       y^j_{i} = \gamma_j'd_i + A^j(p) + \zeta^j_i.
# $$
# <br>

# %% [markdown]
# * ### *Integrating household characteristics with food prices yields valuable insights into the factors shaping household spending on various food items. This amalgamation enables the analysis of correlations between household demographics, such as size, and external factors like food prices across specific regions and years.*
#
# > __This merged dataset facilitates addressing inquiries such as:__
# > - __*How do fluctuations in food prices influence household expenditures on different food items?*__
# > - __*Do variations in household size or composition lead to differences in food purchasing patterns?*__
# > - __*Which food items exhibit greater sensitivity to price fluctuations, and how does this sensitivity vary across regions and demographic groups?*__
#
# <br>

# %%
# Combining prices_pound and HH_characteristics_1
price_url = 'https://docs.google.com/spreadsheets/d/1sfnKHSTXRyLhcDUbVVyVFxyuq6qsp68y9sPkDS-FjgE/edit#gid=2085637103'
prices_1 = read_sheets(price_url, sheet='Food Prices', nheaders=2)
prices_pound = prices_1.loc[(slice(None), "pound"), :].T  # Filter out all rows that don't have column value "pound" and make it a new dataframe


# Dataframe Formatting for prices_value
prices_pound.columns.names = ['w', 'm']
prices_pound = prices_pound.droplevel('m', axis=1)
prices_pound = prices_pound.T
prices_pound.columns.names = ['t', 'm']
prices_pound = prices_pound.T
prices_pound.index = prices_pound.index.set_levels(prices_pound.index.levels[0].astype(int), level=0)  # Convert year of string type to numeric one.
prices_pound


# Dataframe Formatting for HH_characteristics
HH_characteristics_1 = HH_characteristics.T
HH_characteristics_1 = HH_characteristics_1.droplevel('i', axis=1)
HH_characteristics_1 = HH_characteristics_1.T
HH_characteristics_1


# Combine two Dataframe by matching multi-index
merged_df = pd.merge(HH_characteristics_1, prices_pound, left_index = True, right_index = True, how='left')
merged_df.fillna(0, inplace=True)


# Put the previously-removed household id back to the Dataframe
column_i = HH_characteristics.index.get_level_values('i')
column_i_df = pd.DataFrame(column_i, columns=['i'])
merged_df.reset_index(inplace=True)  # Add index manually


# Final Dataset Formatting
merged_df = pd.concat([column_i_df, merged_df], axis = 1)
merged_df = merged_df.set_index(['i','t','m'])
merged_df.columns.name = 'k'
merged_df.head()
# Out:
# k                            women  boys  men  girls  Males 00-03  \
# i       t    m
# 1997125 1997 Herrera           1.0   1.0  1.0    0.0          0.0
# 1997160 1997 Herrera           2.0   0.0  1.0    0.0          0.0
# 1997170 1997 Bocas Del Toro    1.0   3.0  1.0    4.0          1.0
# 1997177 1997 Bocas Del Toro    4.0   9.0  1.0    5.0          2.0
# 1997178 1997 Bocas Del Toro    2.0   1.0  2.0    2.0          0.0
#
# k                            Females 00-03  Males 04-08  Females 04-08  \
# i       t    m
# 1997125 1997 Herrera                   0.0          0.0            0.0
# 1997160 1997 Herrera                   0.0          0.0            0.0
# 1997170 1997 Bocas Del Toro            2.0          1.0            0.0
# 1997177 1997 Bocas Del Toro            1.0          4.0            1.0
# 1997178 1997 Bocas Del Toro            0.0          0.0            1.0
#
# k                            Males 09-13  Females 09-13  ...  Segundo otro  \
# i       t    m                                           ...
# 1997125 1997 Herrera                 1.0            0.0  ...           0.0
# 1997160 1997 Herrera                 0.0            0.0  ...           0.0
# 1997170 1997 Bocas Del Toro          0.0            1.0  ...           0.0
# 1997177 1997 Bocas Del Toro          1.0            3.0  ...           0.0
# 1997178 1997 Bocas Del Toro          1.0            0.0  ...           0.0
#
# k                            Sodas, Refrescos Y Jugos  Tercer otro  Tomate  \
# i       t    m
# 1997125 1997 Herrera                              0.0          0.0     0.5
# 1997160 1997 Herrera                              0.0          0.0     0.5
# 1997170 1997 Bocas Del Toro                       0.0          0.0     0.7
# 1997177 1997 Bocas Del Toro                       0.0          0.0     0.7
# 1997178 1997 Bocas Del Toro                       0.0          0.0     0.7
#
# k                            Viscera De Res  Visceras De Pollo O Gallina  \
# i       t    m
# 1997125 1997 Herrera                   1.25                          1.1
# 1997160 1997 Herrera                   1.25                          1.1
# 1997170 1997 Bocas Del Toro            1.20                          0.5
# 1997177 1997 Bocas Del Toro            1.20                          0.5
# 1997178 1997 Bocas Del Toro            1.20                          0.5
#
# k                            Yuca  Zanahoria  Zapallo / Chayote  Ñame
# i       t    m
# 1997125 1997 Herrera         0.15        0.5                0.2   0.4
# 1997160 1997 Herrera         0.15        0.5                0.2   0.4
# 1997170 1997 Bocas Del Toro  0.20        0.6                0.3   0.4
# 1997177 1997 Bocas Del Toro  0.20        0.6                0.3   0.4
# 1997178 1997 Bocas Del Toro  0.20        0.6                0.3   0.4
#
# [5 rows x 95 columns]

# %% [markdown]
# <br>
#
# * ### *Regression Setup, Result Saving and Result Overview*

# %%
# To enhance the model's accuracy, we may encounter foods with very low consumption rates, making it challenging to reliably estimate their demand. 
# We can adjust the min_obs parameter; increasing its value will result in dropping more foods from the analysis.
# Expenditures = drop_columns_wo_covariance(Expenditures,min_obs=30)

# Take the logarithm to Expenditures. 
Expenditures_log = np.log(Expenditures)
use = Expenditures_log.index.intersection(merged_df.index)
Expenditures_log = Expenditures_log.loc[use,:]
merged_df_matched = merged_df.loc[use,:]

Expenditures_log = Expenditures_log.stack()
merged_df_matched = merged_df_matched.stack()

# Check that indices are in right places.
assert Expenditures_log.index.names == ['i','t','m','j']
assert merged_df_matched.index.names == ['i','t','m','k']

# Remove Ruplicated Indexes.
Expenditures_log = Expenditures_log.groupby(level = Expenditures_log.index.names).mean()

### Regession SetUp
result = Regression(y = Expenditures_log,d = merged_df_matched)

# %%
# Save and reload result
result.to_pickle('pj4_estimate_result.pickle')
result = cfe.regression.read_pickle('pj4_estimate_result.pickle')

# %%
## This code may take longer than 2 minutes to process.
# If it shows "Kernel Dead", try to delete the pickle file and run the notebook from the top again, it should work.
xhat = result.predicted_expenditures()
xhat
# Out:
# i         t     m                    j
# 20081     2008  Bocas Del Toro       Aceite Vegetal               5.288339
#                                      Ajo                          0.692437
#                                      Arroz                        7.311953
#                                      Azúcar                       3.079029
#                                      Café Y Té                    2.596964
#                                                                     ...
# 20087040  2008  Comarca Ngobe Bugle  Queso (Blanco Y Amarillo)    1.747443
#                                      Raspados Y Duros             1.359181
#                                      Sal                          0.618434
#                                      Sardina Y Atún               3.677415
#                                      Sodas, Refrescos Y Jugos     2.659700
# Length: 416806, dtype: float64

# %% [markdown]
# <br>
#
# ### 📈📊 *__Regression Result Analytics [I] - Model Accuracy:__*

# %%
# Compare predicted logarithmic expenditures with actual expenditures:
# %matplotlib widget
df = pd.DataFrame({'y':Expenditures_log, 'yhat':result.get_predicted_log_expenditures()})
ax = df.plot.scatter(x='yhat',y='y')

# Set the x-axis limits from -3 to 6 and the y-axis limits from -4 to 6
ax.set_xlim(-3, 6) 
ax.set_ylim(-4, 6)
plt.xlabel("Predicted Food Expenditure Value")
plt.ylabel("Actual Food Expenditure Value")
plt.title("Demand Model Accuracy Visualization")
plt.show()

# # Plot a trendline
v = plt.axis()
vmin = np.max([v[0],v[2]])
vmax = np.max([v[1],v[3]])
plt.plot([vmin,vmax],[vmin,vmax], color = 'Salmon')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The figure above presents a scatter plot juxtaposing the predicted food expenditures derived from our regression model against the actual logarithmic food expenditures.*__
# * <span style = "color:#1FF30E">__*The depiction indicates a better level of predictive capability and accuracy within the model after combining the food prices with household characteristics.*__

# %%
# Our predicted result
regression_result = result.gamma

# Seperate the result into prices part and HH_characteristics part
HH_char_regression_result = regression_result.iloc[:, :19]  # First two columns
prices_regression_result = regression_result.iloc[:, 19:]  # Remaining columns

# %% [markdown]
# <br>
#
# ### 📈📊 *__Regression Result Analytics [II] - Coefficients of Household Characteristics:__*

# %%
HH_char_regression_result.head()
# Out:
# k                  women      boys       men     girls  Males 00-03  \
# j
# Aceite Vegetal -0.279741 -0.024983 -0.024060 -0.313845    -0.071561
# Ajo             0.134699 -0.030682 -0.006343  0.100107    -0.027076
# Arroz          -0.490754 -0.301524 -0.285209 -0.429082     0.251868
# Azúcar         -0.172819 -0.409167 -0.447934 -0.141708     0.418831
# Café Y Té       0.074437  0.040152  0.081201  0.055541    -0.036127
#
# k               Females 00-03  Males 04-08  Females 04-08  Males 09-13  \
# j
# Aceite Vegetal       0.201712    -0.035537       0.245528    -0.030347
# Ajo                 -0.166284    -0.048766      -0.162973    -0.006369
# Arroz                0.355174     0.255758       0.396293     0.323543
# Azúcar               0.165032     0.424705       0.162971     0.447470
# Café Y Té           -0.041840    -0.019825      -0.039572    -0.003977
#
# k               Females 09-13  Males 14-18  Females 14-18  Males 19-30  \
# j
# Aceite Vegetal       0.254907    -0.011576       0.271751     0.010277
# Ajo                 -0.138375    -0.003593      -0.116260    -0.009174
# Arroz                0.446158     0.386822       0.448854     0.348911
# Azúcar               0.186949     0.490488       0.176532     0.474475
# Café Y Té           -0.046544    -0.011789      -0.007314    -0.019644
#
# k               Females 19-30  Males 31-50  Females 31-50  Males 51-99  \
# j
# Aceite Vegetal       0.300921     0.035420       0.362683     0.054342
# Ajo                 -0.131387     0.015281      -0.083056     0.042628
# Arroz                0.454263     0.376193       0.416498     0.374652
# Azúcar               0.171011     0.506233       0.190854     0.568229
# Café Y Té           -0.032832     0.068431       0.051626     0.144316
#
# k               Females 51-99  log HSize
# j
# Aceite Vegetal       0.305659   0.343150
# Ajo                 -0.089703   0.190649
# Arroz                0.441405   0.583224
# Azúcar               0.224298   0.359284
# Café Y Té            0.101503  -0.030925

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*Each cell in the table above corresponds to the coefficient of household characteristics in our regression model, representing the sought-after outcome of our regression analysis.*__
# * <span style = "color:#1FF30E">__*For example, in the first cell, a value of -0.279741 signifies the average reduction in <u>"Aceite Vegetal" (Vegetable oil) </u>consumption by 0.279741 units for each additional woman in a Panamanian household.*__

# %%
def plot_two_gamma_table(gamma_table, population_groups):
    """
    Ths function is designed to help combine two bar charts displaying food expenditure changes with variations of household composition, and do the comparision.
    
    Parameters:
    - gamma_table (DataFrame): The gamma table above.
    - population_group (list): It should be a list of two population group (string) from the header of gamma table

    Returns:
    - A bar chart described above.
    
    """
    fig, ax = plt.subplots(figsize=(10, 6))
    width = 0.7 
    num_groups = len(population_groups)
    bar_width = width / num_groups  # Adjusting the bar width for multiple groups
    colors = ['#228b22', '#ff7f0e']
    for i, population_group in enumerate(population_groups):
        x = range(len(gamma_table.index))
        ax.bar([pos + i * bar_width for pos in x], gamma_table[population_group], bar_width, label=population_group, color=colors[i])

    ax.set_title(f'Comparision of Household Food Expenditure Changes\n between Population Group [{population_groups[0]}] and [{population_groups[1]}] in Panama')
    ax.set_xlabel('Foods')
    ax.set_ylabel('Change in Food Expenditures')
    ax.set_xticks([pos + width / 2 for pos in x])
    ax.set_xticklabels(gamma_table.index, rotation=90, fontsize=5)
    ax.legend()
    plt.tight_layout()
    plt.show()

print('Please choose from the following:\n"women", "boys", "men", "girls", "Males 00-03", "Females 00-03", "Males 04-08", "Females 04-08", "Males 09-13", "Females 09-13", "Males 14-18", "Females 14-18",\n "Males 19-30", "Females 19-30", "Males 31-50", "Females 31-50", "Males 51-99", "Females 51-99"')
print("\n")  
population_input_list_1 = input('Please input the first population group you would like to visualize (No quotation mark required): ')
print("\n")  
population_input_list_2 = input('Please input a population group you would like to visualize and compare with the first chosen one (No quotation mark required): ')

population_groups = [population_input_list_1, population_input_list_2]  # List of population groups
plot_two_gamma_table(HH_char_regression_result, population_groups)
# Out:
# Please choose from the following:
# "women", "boys", "men", "girls", "Males 00-03", "Females 00-03", "Males 04-08", "Females 04-08", "Males 09-13", "Females 09-13", "Males 14-18", "Females 14-18",
#  "Males 19-30", "Females 19-30", "Males 31-50", "Females 31-50", "Males 51-99", "Females 51-99"
# Please input the first population group you would like to visualize (No quotation mark required):  women
# Please input a population group you would like to visualize and compare with the first chosen one (No quotation mark required):  men
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*Using women and men as examples, notable observations extend beyond the straightforward comparison of bar lengths in the figure.*__
# * <span style = "color:#1FF30E">__*For instance, a distinct contrast in <u>"Cebolla" (onion) </u> consumption between genders within households is apparent: men tend to decrease <u>"Cebolla" (onion) </u> consumption, while women in the same age group tend to increase it. This highlights potential policy disparities related to gender or age groups.*__
# * <span style = "color:#1FF30E">__*Additionally, exploring exceptionally long bars, such as men's consumption in <u>"Sodas, Refrescos Y Jugos" (Sodas, Soft Drinks, and Juices) </u> and <u>"Pan De Sal Y Pan De Dulce" (Bread of salt and sweet bread) </u>, could provide valuable insights.*__

# %% [markdown]
# <br>
#
# ### 📈📊 *__Regression Result Analytics [III] - Coefficients of Food Prices:__*

# %%
prices_regression_result.head()

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The table above resembles an economic demand system, where each cell represents the change in consumption of a specific type of food given a one-unit increase in the price per pound.*__
# * <span style = "color:#1FF30E">__*For instance, in the first cell with a value of -0.001241, for every one-unit increase in the price per pound of <u>"Aceite Vegetal" (vegetable oil)</u>, households are expected to reduce their consumption of <u>"Aceite Vegetal"</u> by 0.001241 units.*__
# * <span style = "color:#1FF30E">__*However, due to data limitations, we only have food prices for 1997 and 2003, and thus, we lack the full range of price changes for specific foods. Consequently, we cannot directly correlate this data with the formal economic demand trend in price-quantity coordinates.*__

# %%
def plot_two_gamma_table(gamma_table, population_groups):
    """
    Ths function is designed to help combine two bar charts displaying food expenditure changes with variations of household composition, and do the comparision.
    
    Parameters:
    - gamma_table (DataFrame): The gamma table above.
    - population_group (list): It should be a list of two population group (string) from the header of gamma table

    Returns:
    - A bar chart described above.
    
    """
    fig, ax = plt.subplots(figsize=(10, 6))
    width = 0.7 
    num_groups = len(population_groups)
    bar_width = width / num_groups  # Adjusting the bar width for multiple groups
    colors = ['#FF00FF', '#823131']
    for i, population_group in enumerate(population_groups):
        x = range(len(gamma_table.index))
        ax.bar([pos + i * bar_width for pos in x], gamma_table[population_group], bar_width, label=population_group, color=colors[i])

    ax.set_title(f'Comparision of Household Food Expenditure Changes\n With Prices of [{population_groups[0]}] and [{population_groups[1]}] in Panama')
    ax.set_xlabel('Foods')
    ax.set_ylabel('Change in Food Expenditures')
    ax.set_xticks([pos + width / 2 for pos in x])
    ax.set_xticklabels(gamma_table.index, rotation=90, fontsize=5)
    ax.legend()
    plt.tight_layout()
    plt.show()

print("Please choose from the following:\n'Aceite Vegetal', 'Ajo', 'Arroz', 'Azúcar', 'Café Y Té','Carnes De Puerco', 'Cebolla', 'Cereales Y Cremas','Cigarrillo Y Tabaco', 'Embutidos', 'Galletas / Pasteles Y Dulces','Harina De Trigo', 'Huevos De Gallina', 'Lecha Evaporada', 'Lentejas','Pan De Sal Y Pan De Dulce', 'Pastas Alimenticias', 'Pastas De Tomate','Pescados', 'Pollo O Gallina', 'Porotos', 'Queso (Blanco Y Amarillo)','Raspados Y Duros', 'Sal', 'Sardina Y Atún','Sodas, Refrescos Y Jugos'")
print("\n")  
population_input_list_1 = input('Please input the first food you would like to visualize (No quotation mark required): ')
print("\n")  
population_input_list_2 = input('Please input the food you would like to visualize and compare with the first chosen one (No quotation mark required): ')

population_groups = [population_input_list_1, population_input_list_2]  # List of population groups
plot_two_gamma_table(prices_regression_result, population_groups)
# Out:
# Please choose from the following:
# 'Aceite Vegetal', 'Ajo', 'Arroz', 'Azúcar', 'Café Y Té','Carnes De Puerco', 'Cebolla', 'Cereales Y Cremas','Cigarrillo Y Tabaco', 'Embutidos', 'Galletas / Pasteles Y Dulces','Harina De Trigo', 'Huevos De Gallina', 'Lecha Evaporada', 'Lentejas','Pan De Sal Y Pan De Dulce', 'Pastas Alimenticias', 'Pastas De Tomate','Pescados', 'Pollo O Gallina', 'Porotos', 'Queso (Blanco Y Amarillo)','Raspados Y Duros', 'Sal', 'Sardina Y Atún','Sodas, Refrescos Y Jugos'
# Please input the first food you would like to visualize (No quotation mark required):  Ajo
# Please input the food you would like to visualize and compare with the first chosen one (No quotation mark required):  Arroz
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*This visualization of the table allows us to compare the price sensitivity of different foods and their related counterparts.*__
# * <span style = "color:#1FF30E">__*Taking the longest bar as an example, both <u>"Arroz" (rice) </u> and <u>"Ajo" (garlic) </u> exhibit a decrease in consumption as the price of <u> "Pan De Sal Y Pan De Dulce" (Bread of salt and sweet bread) </u> increases. However, it's evident that <u>"Ajo" </u>is approximately five times more sensitive than <u> "Arroz" </u>, as indicated by the significantly longer bar.*__
# * <span style = "color:#1FF30E">__*Zooming out and examining the overall graph, you might notice that for most pairs of bars, <u> "Ajo" </u> consistently exhibits longer bars than <u>"Arroz"</u>. In other words, <u>"Arroz" (rice)</u> is more "inelastic" to price changes compared to foods related to <u>"Ajo" (garlic) </u>. This suggests the potential for tailored policy interventions for these two typical food types.*__

# %%
# Avoid Memory Overload
# plt.close('all')

# Change Dataframe display setting
# pd.options.display.max_rows = 1000

# %% [markdown]
# <br>
#
#
# ## __[A] Construct Nutrient System__
#
# * ### *Main Nutrient System Equation:*
#
# <br>
#
# $$
#       N^j_{i} = A^j(p) + \beta_j w_i + \zeta^j_i.
# $$
# <br>
#
# > $N^j_{i}$ : *__Nutrient amount on food $j$ of household $i$ .__*
# >
# > $A^j(p)$ : *__Sub-function of price $p$ of food $j$. It captures the demand elasticity of food $j$ .__*
# >
# > $\beta_j w_i$ : *__Variable $w_i$ represents household wealth (budget). The coefficient $\beta_j$ indicates how changes in household budget affect household's nutrient intakes.__*
# >
# > $\zeta^j_i$ : *__The error term represents all sources of variation in the dependent variable ($y_{i}^j$) that are not explained by the independent variables included in regression function.__*

# %%
# Take the median of prices per pound of all regions in specific year
with warnings.catch_warnings():
    warnings.simplefilter("ignore", FutureWarning)
    prices_per_lb = prices.T.groupby('t', axis=1).median().xs('pound', level='u')

prices_per_lb.columns = [1997,2003]  # prices_per_lb is derived from Dataframe "prices"

# Implied relative prices
p_result = np.exp(result.get_Ar())

# %%
# Generates an array of 20 evenly spaced numbers from 0.5 to 2.
scale = np.linspace(.5,2,20)

# Total food expenditures per household
xbar = xhat.groupby(['i','t','m']).sum()

# Reference budget
xref = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# Reference prices - Calculate the average price for each food item across all observations.
pbar = p_result.groupby(level='j').mean()

def my_prices(p0, p = pbar, j = 'Arroz'):
    """
    This changes the food prices of good j while holding other food prices unchanged
    
    p0 - The price you want to change
    p - The price dataframe you want to make changes
    j - The specific food that you want to make changes in their price.
    """
    p_copy = p.copy()
    p_copy.loc[j] = p0
    return p_copy

# xhat is the predicted expenditure on foods, and prices_per_lb is the food prices per pounds. 
# Then qhat is the predicted food quantities of each household
xhat_unstack = xhat.unstack('j').xs(1997, level = 't')
qhat = xhat_unstack / prices_per_lb[1997]

# Drop missing columns
qhat = qhat.loc[:, qhat.count() > 0]

# %%
def nutrient_demand(x, p):
    """
    This function computes nutrition as a function of prices and budget.
    
    x - A list of potential budget based on food expenditure
    p - The average price for each food item across all observations.
    """
    c = result.demands(x, p)
    # Create a new FCT and vector of consumption that only share rows in common:
    fct0,c0 = fct.align(c,axis=0,join='inner')
    # N is weekly nutrient amount of each household.
    N = fct0.T@c0  # The @ operator means matrix multiply
    N = N.loc[~N.index.duplicated()]
    return N

# Create a list of potential budget based on food expenditure
X = np.linspace(xref/5, xref*5, 50)

UseNutrients = ['Energía','Proteina','Fibra Diet. total','Vit. A Equiv. Retinol','Vit. C']

# %% [markdown]
# <br>
#
# ### 📈📊 *__Nutrient System Analytics [I] - Describe Nutrient Amount as A Function of Household Budget:__*
#
# <br>
#
# $$
#       N^j_{i} = \beta_j w_i + \zeta^j_i.
# $$
#
# <br>

# %%
df = pd.concat({myx:np.log(nutrient_demand(myx,pbar))[UseNutrients] for myx in X},axis=1).T
ax = df.plot()

ax.set_xlabel('Logarithmic Budget')
ax.set_ylabel('Logarithmic Nutrient')
ax.set_title("Household Nutrient Amount Changes in Response to Budget Changes")
# Out:
# Text(0.5, 1.0, 'Household Nutrient Amount Changes in Response to Budget Changes')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*This graph illustrates how nutrient levels change in response to fluctuations in the average household budget.*__
# * <span style = "color:#1FF30E">__*From a broad perspective, we observe that all nutrient levels increase alongside the household budget.*__
# * <span style = "color:#1FF30E">__*However, upon closer examination, we notice that at lower budget levels, there is a significant spike in nutrient intake, but as the budget increases further, the rate of increase in nutrient levels diminishes. This indicates a diminishing marginal change in nutrient demand relative to budget.*__
# * <span style = "color:#1FF30E">__*Additionally, when analyzing the slope of each nutrient, we observe that energy, protein, vitamin A, and vitamin C follow a similar trajectory of change, while fiber exhibits a more gradual increase with a shallower slope.*__

# %% [markdown]
# <br>
#
# ### 📈📊 *__Nutrient System Analytics [II] - Describe Nutrient Amount as A Function of Food Price:__*
#
# <br>
#
# $$
#       N^j_{i} = A^j(p) + \zeta^j_i.
# $$
#
# <br>

# %%
print("Please choose from the following:\n'Aceite Vegetal', 'Ajo', 'Arroz', 'Azúcar', 'Café Y Té', 'Carnes De Puerco', 'Cebolla', 'Cereales Y Cremas', 'Cigarrillo Y Tabaco', 'Embutidos', 'Galletas / Pasteles Y Dulces', 'Harina De Trigo', 'Huevos De Gallina', 'Lecha Evaporada', 'Lentejas', 'Pan De Sal Y Pan De Dulce', 'Pastas Alimenticias', 'Pastas De Tomate', 'Pescados', 'Pollo O Gallina', 'Porotos', 'Queso (Blanco Y Amarillo)', 'Raspados Y Duros', 'Sal', 'Sardina Y Atún', 'Sodas, Refrescos Y Jugos'")
print("\n")
USE_GOOD = input("Please input the food name you would like to query (No quotation mark required): ")
print("\n")

scale = np.geomspace(.01,10,50)
ndf = pd.DataFrame({s:np.log(nutrient_demand(xref/2,my_prices(pbar[USE_GOOD]*s,j=USE_GOOD)))[UseNutrients] for s in scale}).T
ax = ndf.plot()
ax.set_xlabel('Logarithmic Price')
ax.set_ylabel('Logarithmic Nutrient')
ax.set_title(f"Household Nutrient Amount Changes in Response to Price Changes in [{USE_GOOD}]")
# Out:
# Please choose from the following:
# 'Aceite Vegetal', 'Ajo', 'Arroz', 'Azúcar', 'Café Y Té', 'Carnes De Puerco', 'Cebolla', 'Cereales Y Cremas', 'Cigarrillo Y Tabaco', 'Embutidos', 'Galletas / Pasteles Y Dulces', 'Harina De Trigo', 'Huevos De Gallina', 'Lecha Evaporada', 'Lentejas', 'Pan De Sal Y Pan De Dulce', 'Pastas Alimenticias', 'Pastas De Tomate', 'Pescados', 'Pollo O Gallina', 'Porotos', 'Queso (Blanco Y Amarillo)', 'Raspados Y Duros', 'Sal', 'Sardina Y Atún', 'Sodas, Refrescos Y Jugos'
# Please input the food name you would like to query (No quotation mark required):  Arroz
# Text(0.5, 1.0, 'Household Nutrient Amount Changes in Response to Price Changes in [Arroz]')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The graph depicts how nutrient levels respond to changes in the price of specific foods.*__
# * <span style = "color:#1FF30E">__*Initially, there is a general trend of decreasing nutrient levels as food prices rise.*__
# * <span style = "color:#1FF30E">__*However, a closer examination reveals nuances in this relationship. At lower price levels, there is a notable increase in nutrient intake, but as prices escalate further, the rate of nutrient level increase slows down. This suggests a diminishing marginal change in nutrient demand relative to food price.*__
# * <span style = "color:#1FF30E">__*For instance, consider <u>Leche Evaporada (evaporated milk)</u>: as its price increases, nutrients such as energy, protein, vitamin A, and vitamin C experience substantial drops, particularly vitamin A. In contrast, the line representing fiber remains almost flat, indicating that the fiber content in this food remains relatively unaffected by price changes. This suggests that fiber content in this food is inelastic to price changes.*__
# * <span style = "color:#f44336">__*From a policy standpoint, this implies that <u>Leche Evaporada</u> could be a strategic choice for adjusting people's vitamin A intake, but it may not be an effective proxy for regulating fiber intake.*__.

# %% [markdown]
# <br>
#
#
# ## __[A] Nutritional Challenges & Policy Goal__
#
# ### 📈📊 *__Nutritional Challenges Analytics [I] - Visualization:__*

# %%
use = fct.index.intersection(qhat.columns)

# qhat is predicted food quantities of each household, and fct is the nutrition amount of each specific food. 
# Hence, we use qhat * fct to get the nutrient amount of each household.
nutrients = qhat[use]@fct.loc[use, :]

# %%
# Define a mapping dictionary to rename columns in hh_characteristics DataFrame
column_mapping = {
    'Males 00-03': 'Males 00-03',
    'Females 00-03': 'Females 00-03',
    'Males 04-08': 'Males 04-08',
    'Females 04-08': 'Females 04-08',
    'Males 09-13': 'Males 09-13',
    'Females 09-13': 'Females 09-13',
    'Males 14-18': 'Males 14-18',
    'Females 14-18': 'Females 14-18',
    'Males 19-30': 'Males 19-30',
    'Females 19-30': 'Females 19-30',
    'Males 31-50': 'Males 31-50',
    'Females 31-50': 'Females 31-50',
    'Males 51-99': 'Males 51-99',
    'Females 51-99': 'Females 51-99',
    'log HSize': 'log HSize'
}

nutrient_translation = {'Energía':'Energy',
                       'Proteina': 'Protein',
                       'Fibra Diet. total' : 'Fiber',
                       'Ac. Folico' : 'Folate',
                       'Calcio' : 'Calcium',
                      'Carbo-hidratos' : 'Carbohydrate',
                      'Hierro': 'Iron',
                       'Fosforo' : 'Phosphorus',
                       'Vit. A Equiv. Retinol' : 'Vitamin A',
                      'Magnesio' : 'Magnesium',
                      'Niacina' : 'Niacin',
                      'Potasio' : 'Potassium',
                      'Vit. B12' : 'Vitamin B-12',
                      'Vit.B6' : 'Vitamin B-6',
                      'Vit. C' : 'Vitamin C',
                      'Zinc' : 'Zinc'}

nutrients_eng = nutrients.rename(columns = nutrient_translation)  # Thanslate to English

# Rename columns in hh_characteristics DataFrame using the mapping dictionary
hh_characteristics_eng = HH_characteristics.rename(columns = column_mapping)

hh_characteristics_eng = hh_characteristics_eng[column_mapping.values()]

hh_characteristics_eng_select = hh_characteristics_eng[rdi.columns.tolist()]

# %%
# hh_rdi is the recommended nutrient amount of each household
hh_rdi = hh_characteristics_eng_select@rdi.T

# Check recommended weekly intake
hh_rwi = hh_rdi * 7
use_nutrients = nutrients_eng.columns.intersection(hh_rwi.columns)

# nutrients_eng is weekly nutrient amount of each household.
# The ratio represents the actual VS. recommended nutrient amount
# Greater than one ---> actual amount exceeds the recommended one
nutrient_ratio = (nutrients_eng[use_nutrients] / hh_rwi[use_nutrients]).dropna()

# %%
# If it outputs a series of graphs, try to run this code block again. The correct graph should appear.
# %matplotlib inline
print("Please choose from the following:\n'Energy', 'Protein', 'Carbohydrate', 'Fiber', 'Calcium', 'Phosphorus', 'Iron', 'Niacin', 'Vitamin C', 'Vitamin A', 'Potassium', 'Zinc', 'Magnesium', 'Vitamin B-12'")
print("\n")
USE_nutrient_name = input("Please input the nutrient name you would like to query (No quotation mark required): ")
print("\n")
USE_nutrient_name = str(USE_nutrient_name)
nutrient_ratio[USE_nutrient_name].hist(bins=100,range = (0,1))
plt.xlabel("Ratio")
plt.ylabel("Household Amount")
plt.title(f"Distribution of Households' [{USE_nutrient_name}] Ratio \n(Ratio = Actual Nutrient Amount / Recommended Nutrient Amount)")

# Add a red vertical line at x = 1.0
plt.axvline(x=1.0, color='red', linestyle='--', label='Nutrient Recommended Standard', linewidth=4)

# Add a blue vetical line for averayge
average_amount = nutrient_ratio.mean()[USE_nutrient_name]
plt.axvline(x=average_amount, color='#7AF30E', linestyle='-.', linewidth=3, label='Actual Average Amount')

plt.legend()
plt.show()
# Out:
# Please choose from the following:
# 'Energy', 'Protein', 'Carbohydrate', 'Fiber', 'Calcium', 'Phosphorus', 'Iron', 'Niacin', 'Vitamin C', 'Vitamin A', 'Potassium', 'Zinc', 'Magnesium', 'Vitamin B-12'
# Please input the nutrient name you would like to query (No quotation mark required):  Vitamin A

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*This histogram displays the distribution of nutrient ratios across households. The ratio is calculated by dividing the actual amount of a specific nutrient by the recommended amount.*__
# * <span style = "color:#1FF30E">__*A ratio of 1 indicates that the actual nutrient intake matches the recommended intake, which is the ideal scenario denoted by the red line. Each bar's height represents the number of households corresponding to that particular ratio.*__
# * <span style = "color:#1FF30E">__*The blue line represents the average ratio across all households.*__
# * <span style = "color:#1FF30E">__*In the case of vitamin A, for example, the blue line is positioned noticeably to the left of the red line. This indicates that the majority of households have an insufficient intake of vitamin A relative to the recommended amount.*__
# * <span style = "color:#f44336">__*Therefore, this observation highlights the focus of our policy efforts towards addressing inadequate vitamin A intake in households.*__

# %% [markdown]
# <br>
#
# ### 📈📊 *__Nutritional Challenge Analytics [II] - Nutritional Data Comparison:__*
# <br>
#
# * ### *To ensure a more precise comparison of nutrients, we will create a DataFrame for it.*

# %%
actual_nutrients = nutrients_eng[use_nutrients].mean()
recommended_nutrients = hh_rwi[use_nutrients].mean()

def comparision_table(actual_nutrients_example, recommended_nutrients_example):
    # Create a DataFrame from the two series
    df = pd.DataFrame({'Actual Nutrients': actual_nutrients_example, 'Recommended Nutrients': recommended_nutrients_example})
    
    # Add a column for the difference
    df['Difference'] = df['Actual Nutrients'] - df['Recommended Nutrients']
    
    # Add a column for marking excessive or insufficient
    status_list = []
    for diff in df['Difference']:
        if diff > 1000:
            status_list.append('Excessive')
        elif diff < -1000:
            status_list.append('Insufficient')
        elif abs(diff) <= 1000:
            status_list.append('Satisfy')
        else:
            status_list.append(None)

    df['Status'] = pd.Series(status_list, index=df.index)

    
    # Function to apply cell styling based on status
    def color_cell(val):
        if val == 'Excessive':
            return 'background-color: red'
        elif val == 'Insufficient':
            return 'background-color: skyblue'
        elif val == 'Satisfy':
            return 'background-color: lime'
    
    # Apply styling to the 'Status' column
    styled_df = df.style.map(color_cell, subset=['Status'])

    return styled_df

whole_hh = comparision_table(actual_nutrients, recommended_nutrients)
whole_hh
# Out:
# <style type="text/css">
# #T_6c53e_row0_col3, #T_6c53e_row4_col3, #T_6c53e_row7_col3, #T_6c53e_row8_col3, #T_6c53e_row9_col3, #T_6c53e_row11_col3 {
#   background-color: skyblue;
# }
# #T_6c53e_row1_col3, #T_6c53e_row3_col3, #T_6c53e_row6_col3, #T_6c53e_row10_col3, #T_6c53e_row12_col3 {
#   background-color: lime;
# }
# #T_6c53e_row2_col3, #T_6c53e_row5_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_6c53e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c53e_level0_col0" class="col_heading level0 col0" >Actual Nutrients</th>
#       <th id="T_6c53e_level0_col1" class="col_heading level0 col1" >Recommended Nutrients</th>
#       <th id="T_6c53e_level0_col2" class="col_heading level0 col2" >Difference</th>
#       <th id="T_6c53e_level0_col3" class="col_heading level0 col3" >Status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >n</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c53e_level0_row0" class="row_heading level0 row0" >Energy</th>
#       <td id="T_6c53e_row0_col0" class="data row0 col0" >43080.452874</td>
#       <td id="T_6c53e_row0_col1" class="data row0 col1" >51592.349608</td>
#       <td id="T_6c53e_row0_col2" class="data row0 col2" >-8511.896734</td>
#       <td id="T_6c53e_row0_col3" class="data row0 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row1" class="row_heading level0 row1" >Protein</th>
#       <td id="T_6c53e_row1_col0" class="data row1 col0" >1487.922575</td>
#       <td id="T_6c53e_row1_col1" class="data row1 col1" >1199.444202</td>
#       <td id="T_6c53e_row1_col2" class="data row1 col2" >288.478373</td>
#       <td id="T_6c53e_row1_col3" class="data row1 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row2" class="row_heading level0 row2" >Carbohydrate</th>
#       <td id="T_6c53e_row2_col0" class="data row2 col0" >7376.747309</td>
#       <td id="T_6c53e_row2_col1" class="data row2 col1" >3716.312663</td>
#       <td id="T_6c53e_row2_col2" class="data row2 col2" >3660.434646</td>
#       <td id="T_6c53e_row2_col3" class="data row2 col3" >Excessive</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row3" class="row_heading level0 row3" >Fiber</th>
#       <td id="T_6c53e_row3_col0" class="data row3 col0" >200.574820</td>
#       <td id="T_6c53e_row3_col1" class="data row3 col1" >722.292895</td>
#       <td id="T_6c53e_row3_col2" class="data row3 col2" >-521.718074</td>
#       <td id="T_6c53e_row3_col3" class="data row3 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row4" class="row_heading level0 row4" >Calcium</th>
#       <td id="T_6c53e_row4_col0" class="data row4 col0" >5239.057867</td>
#       <td id="T_6c53e_row4_col1" class="data row4 col1" >30124.754795</td>
#       <td id="T_6c53e_row4_col2" class="data row4 col2" >-24885.696928</td>
#       <td id="T_6c53e_row4_col3" class="data row4 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row5" class="row_heading level0 row5" >Phosphorus</th>
#       <td id="T_6c53e_row5_col0" class="data row5 col0" >23495.852876</td>
#       <td id="T_6c53e_row5_col1" class="data row5 col1" >22095.653335</td>
#       <td id="T_6c53e_row5_col2" class="data row5 col2" >1400.199542</td>
#       <td id="T_6c53e_row5_col3" class="data row5 col3" >Excessive</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row6" class="row_heading level0 row6" >Iron</th>
#       <td id="T_6c53e_row6_col0" class="data row6 col0" >425.553028</td>
#       <td id="T_6c53e_row6_col1" class="data row6 col1" >307.683032</td>
#       <td id="T_6c53e_row6_col2" class="data row6 col2" >117.869996</td>
#       <td id="T_6c53e_row6_col3" class="data row6 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row7" class="row_heading level0 row7" >Vitamin C</th>
#       <td id="T_6c53e_row7_col0" class="data row7 col0" >146.696909</td>
#       <td id="T_6c53e_row7_col1" class="data row7 col1" >1848.361214</td>
#       <td id="T_6c53e_row7_col2" class="data row7 col2" >-1701.664306</td>
#       <td id="T_6c53e_row7_col3" class="data row7 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row8" class="row_heading level0 row8" >Vitamin A</th>
#       <td id="T_6c53e_row8_col0" class="data row8 col0" >3213.056676</td>
#       <td id="T_6c53e_row8_col1" class="data row8 col1" >19691.886443</td>
#       <td id="T_6c53e_row8_col2" class="data row8 col2" >-16478.829767</td>
#       <td id="T_6c53e_row8_col3" class="data row8 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row9" class="row_heading level0 row9" >Potassium</th>
#       <td id="T_6c53e_row9_col0" class="data row9 col0" >17654.324130</td>
#       <td id="T_6c53e_row9_col1" class="data row9 col1" >126563.867698</td>
#       <td id="T_6c53e_row9_col2" class="data row9 col2" >-108909.543569</td>
#       <td id="T_6c53e_row9_col3" class="data row9 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row10" class="row_heading level0 row10" >Zinc</th>
#       <td id="T_6c53e_row10_col0" class="data row10 col0" >95.201486</td>
#       <td id="T_6c53e_row10_col1" class="data row10 col1" >237.394671</td>
#       <td id="T_6c53e_row10_col2" class="data row10 col2" >-142.193185</td>
#       <td id="T_6c53e_row10_col3" class="data row10 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row11" class="row_heading level0 row11" >Magnesium</th>
#       <td id="T_6c53e_row11_col0" class="data row11 col0" >4476.424206</td>
#       <td id="T_6c53e_row11_col1" class="data row11 col1" >8623.544573</td>
#       <td id="T_6c53e_row11_col2" class="data row11 col2" >-4147.120367</td>
#       <td id="T_6c53e_row11_col3" class="data row11 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_6c53e_level0_row12" class="row_heading level0 row12" >Vitamin B-12</th>
#       <td id="T_6c53e_row12_col0" class="data row12 col0" >37.846714</td>
#       <td id="T_6c53e_row12_col1" class="data row12 col1" >59.069137</td>
#       <td id="T_6c53e_row12_col2" class="data row12 col2" >-21.222422</td>
#       <td id="T_6c53e_row12_col3" class="data row12 col3" >Satisfy</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*From the table above, you can clearly discern the comparison between the actual and recommended nutrient amounts in precise numerical values. It allows for a straightforward assessment of the disparities, indicating whether the actual intake exceeds or falls short of the recommended values and by how much. This information is crucial for informing policy decisions regarding specific nutrient adequacy or insufficiency.*__
# * <span style = "color:#1FF30E">__*Additionally, we have established criteria wherein a nutrient difference with an absolute value of less than 1000 is deemed to meet the recommended amount. Notably, Protein, Fiber, Iron, Zinc, and Vitamin B-12 fall within the acceptable interval of [-1000, 1000], as demonstrated.*__

# %%
# Visualization of the differences in the table above
df_original = whole_hh.data  # Extract the underlying DataFrame

# Plot the difference
df_original['Difference'].plot(kind='bar')
plt.xlabel('Nutrients')
plt.ylabel('Difference')
plt.title('Difference between Actual and Recommended Nutrients')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The graph above provides a visual representation of the disparities in nutrient amounts, clearly illustrating the magnitude of the differences. It is evident that Potassium exhibits a notably high level of inefficiency, indicating a significant deficiency in this essential nutrient.*__

# %% [markdown]
# <br>
#
#
# ## __[B] Policy Options__
#
# ### _Upon reviewing the table above, it's evident that there are both excessive and insufficient amounts of nutrients within the average household. With this in mind, we propose a <span style = "color:red"> Policy Bundle </span> that can simultaneously address both excessive and insufficient nutrient intake:_
#
# > * ### __Taxation__ _: Designate a tax on a select food item abundant in the nutrients that are listed above. The tax policy is based on all the households._
#
# > * ### __Food Stamp (Subsidy)__ _: Allocate food stamps towards a specific food insufficient in specific nutrients. The food stamp policy is based on households with more than one child._
#
# <br>

# %% [markdown]
# ### 🏛️📚 *__Policy [I]: Taxation:__*
#
# * ### *Using the table above, we first identify nutrients that are excessively consumed. We then select a food rich in these nutrients to tax. The choice of food to tax is informed by a graph in our code, which illustrates how nutrient intake varies with changes in food prices (AKA nutritional elasticity).*
# * ### *The table above indicates that the intake of Protein, Carbohydrates, Phosphorus and Iron is excessive in Panamanian households. In response, we aim to identify the food item with the highest content of these nutrients and propose a tax on this food.*

# %%
# Normalize the nutrients columns in fct (if not already normalized)
nutrients_tax = ['Fosforo', 'Hierro', 'Proteina', 'Carbo-hidratos']
fct_tax = fct.copy()
fct_tax[nutrients_tax] = fct_tax[nutrients_tax].apply(lambda x: x / x.max())

# Calculate a Combined Score 
fct_tax['Total_Score'] = fct_tax[nutrients_tax].sum(axis=1)

# Filter fct DataFrame to only include items that are also in pabr
common_foods = fct_tax[fct_tax.index.isin(pbar.index)]

# Sort the common foods by Total Score in descending order
ranked_common_foods = common_foods.sort_values(by='Total_Score', ascending=False)

# Print the sorted list of common foods with their scores
print(ranked_common_foods[['Total_Score']])
# Out:
# n                             Total_Score
# j
# Lentejas                         1.766091
# Porotos                          1.649312
# Cereales Y Cremas                1.336773
# Arroz                            1.267470
# Pastas Alimenticias              1.233020
# Harina De Trigo                  1.178092
# Azúcar                           1.003556
# Galletas / Pasteles Y Dulces     0.945481
# Queso (Blanco Y Amarillo)        0.833409
# Pan De Sal Y Pan De Dulce        0.832145
# Sardina Y Atún                   0.778631
# Embutidos                        0.613704
# Ajo                              0.583622
# Carnes De Puerco                 0.579763
# Pescados                         0.549212
# Huevos De Gallina                0.494230
# Pollo O Gallina                  0.481991
# Lecha Evaporada                  0.474316
# Raspados Y Duros                 0.340230
# Pastas De Tomate                 0.334650
# Cebolla                          0.194178
# Sal                              0.007500
# Café Y Té                        0.005983
# Sodas, Refrescos Y Jugos         0.000227
# Aceite Vegetal                   0.000000

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*Given the observation that Lentejas (translated to 'lentils' in English) possess the highest combined nutrient score among the listed foods, it's worth considering the implementation of a tax on this particular item.*__

# %% [markdown]
# ## 🚨🚨🚨 *__<span style = "color:#F3500E">Lentejas (lentils) Taxation Policy Interpretation:__*
#
#
# * ### *Our tax policy begins by examining the table provided at the conclusion of our code. We pinpoint nutrients that are consumed excessively based on the data. Subsequently, we identify a food item abundant in these nutrients to subject to taxation. The selection of the food item for taxation is guided by a graphical representation within our code, showcasing the relationship between nutrient intake and fluctuations in food prices, commonly referred to as nutritional elasticity. This comprehensive approach forms the foundation of our initial policy directive.*

# %% [markdown]
# <br>
#
# * ### *Let's take a look at its original demand curve first.*

# %%
# %matplotlib inline
use_tax = 'Lentejas'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Millet for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use_tax]*s,pbar))[use_tax] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use_tax]:.2f})")
plt.xlabel(f"Quantities of lentils(Lentejas) Demanded (lb)")
plt.title("Demand Curve (Marginal Benefit Curve) of lentils(Lentejas)")
# Out:
# Text(0.5, 1.0, 'Demand Curve (Marginal Benefit Curve) of lentils(Lentejas)')

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The demand curve for lentils (Lentejas) showcases a distinct downward slope, resembling a nearly linear trajectory. This observation indicates a high degree of responsiveness in the quantity demanded concerning fluctuations in price, suggesting a considerable level of demand elasticity. Given this characteristic, lentils (Lentejas) emerge as a prime candidate for our taxation policy.*__
#
# <br>

# %%
# Demand for Lentils for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use_tax]*s,pbar, use_tax))[use_tax] for s in scale],scale, label='Median Household')

# Demand for Lentils for household at 25% percentile
plt.plot([result.demands(xbar.quantile(0.25),my_prices(pbar[use_tax]*s,pbar, use_tax))[use_tax] for s in scale],scale, label='25th Percentile Household')

# Demand for Lentils for household at 75% percentile
plt.plot([result.demands(xbar.quantile(0.75),my_prices(pbar[use_tax]*s,pbar, use_tax))[use_tax] for s in scale],scale, label='75th Percentile Household')

plt.ylabel(f"Price (relative to base of {pbar[use_tax]:.2f})")
plt.xlabel(f"Quantities of Lentils Demanded (lb)")
plt.legend()
plt.title("Demand Curves for Lentejas at Different Household Budget Percentiles\n- Original Prices-")
plt.show()

# %%
# Check the original price of Lentils
original_price = pbar.loc['Lentejas']

print("Original price of Lentejas(lentils):", original_price)
# Out:
# Original price of Lentejas(lentils): 0.9911663565184179

# %%
# Assuming 'Lentejas' is an index in the DataFrame pbar
original_price = pbar.loc['Lentejas']

# Calculate the new price by increasing it by 50%
new_price = original_price * 1.50

# Update the price in the DataFrame
pbar_tax = pbar.copy()
pbar_tax.loc['Lentejas'] = new_price

# Print the new price
print("New price of Lentejas(lentils) after a 50% increase:", pbar_tax.loc['Lentejas'])
# Out:
# New price of Lentejas(lentils) after a 50% increase: 1.4867495347776267

# %%
# Plotting demand curves for households at different budget percentiles
plt.plot([result.demands(xref, my_prices(new_price * s, pbar, use_tax))[use_tax] for s in scale], scale, label='Median Household')
plt.plot([result.demands(xbar.quantile(0.25), my_prices(new_price * s, pbar, use_tax))[use_tax] for s in scale], scale, label='25% Percentile Household')
plt.plot([result.demands(xbar.quantile(0.75), my_prices(new_price * s, pbar, use_tax))[use_tax] for s in scale], scale, label='75% Percentile Household')

plt.ylabel(f"Price (relative to base of {new_price:.2f})")
plt.xlabel(f"Quantities of {use_tax} Demanded")
plt.legend()
plt.title("Demand Curves for Lentejas at Different Household Budget Percentiles\n-Price increased by 50% (Taxation Policy)-")
plt.show()

# %%
my_j_tax = 'Lentejas'  

P_tax = np.geomspace(.01,10,50)*pbar[my_j_tax]

# Utility of median household, given prices
U0_tax = result.indirect_utility(xref,pbar)

plt.figure(figsize=(8, 5))
plt.plot([result.demands(xref,my_prices(p0,j=my_j_tax))[my_j_tax] for p0 in P_tax],P_tax)
plt.plot([result.demands(U0_tax,my_prices(p0,j=my_j_tax),type="Hicksian")[my_j_tax] for p0 in P_tax],P_tax)

plt.ylabel('Price')
plt.xlabel("Quantity Demanded (Marshallian, Income Fixed) & Utility (Hicksian)")
plt.legend(("Marshallian Curve","Hicksian Curve"))
plt.grid(True)
plt.title("Marshallian Curve and Hicksian Curve for Lentejas(lentils)")
# Out:
# Text(0.5, 1.0, 'Marshallian Curve and Hicksian Curve for Lentejas(lentils)')

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The figure above illustrates the Marshallian Curve and the Hicksian Curve for Lentejas(lentils), both of which display an intriguing parallel trend.*__
# * <span style = "color:#1FF30E">__*The Marshallian demand curve elucidates the correlation between the price of a commodity and the quantity demanded, assuming income remains constant. Conversely, the Hicksian demand curve is influenced by prices and utility.*__
# * <span style = "color:#1FF30E">__*As the price nears zero, consumer utility reaches its zenith, resulting in a surge in the quantity demanded, while income remains unchanged. This phenomenon underscores the significance of price elasticity in consumer behavior, particularly in relation to essential goods like beans.*__
# <br>

# %% [markdown]
# <br>
#
# ### 🏛️📚 *__Policy [II]: Food Stamp:__*
#
#
# * ### *The revenue accrued from the aforementioned tax mechanism serves as a funding reservoir for government-issued food stamps, strategically directed towards <span style = "color:red">households with more than one child</span>. Our objective is to allocate these stamps towards a category of food deficient in specific nutrients.*
#
# * ### *Through the construction of a table akin to the overall-household nutritional dataset above, with a focus on children's nutrient profiles, we aim to pinpoint the food item most lacking in essential nutrients for this demographic.*

# %%
# Create a household characteristics dataframe for households with more than one child.
HH_characteristics_children = HH_characteristics[(HH_characteristics["boys"] > 0) | (HH_characteristics["girls"] > 0)]
HH_id_children = HH_characteristics_children.index.get_level_values('i').tolist()

nutrient_children = nutrients_eng[nutrients_eng.index.get_level_values("i").isin(HH_id_children)]
hh_rwi_children = hh_rwi[hh_rwi.index.get_level_values("i").isin(HH_id_children)]

nutrient_children_actual = nutrient_children[use_nutrients].mean()
hh_rwi_children_actual = hh_rwi_children[use_nutrients].mean()
whole_hh_child = comparision_table(nutrient_children_actual, hh_rwi_children_actual)
whole_hh_child
# Out:
# <style type="text/css">
# #T_129b8_row0_col3, #T_129b8_row4_col3, #T_129b8_row5_col3, #T_129b8_row7_col3, #T_129b8_row8_col3, #T_129b8_row9_col3, #T_129b8_row11_col3 {
#   background-color: skyblue;
# }
# #T_129b8_row1_col3, #T_129b8_row3_col3, #T_129b8_row6_col3, #T_129b8_row10_col3, #T_129b8_row12_col3 {
#   background-color: lime;
# }
# #T_129b8_row2_col3 {
#   background-color: red;
# }
# </style>
# <table id="T_129b8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_129b8_level0_col0" class="col_heading level0 col0" >Actual Nutrients</th>
#       <th id="T_129b8_level0_col1" class="col_heading level0 col1" >Recommended Nutrients</th>
#       <th id="T_129b8_level0_col2" class="col_heading level0 col2" >Difference</th>
#       <th id="T_129b8_level0_col3" class="col_heading level0 col3" >Status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >n</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_129b8_level0_row0" class="row_heading level0 row0" >Energy</th>
#       <td id="T_129b8_row0_col0" class="data row0 col0" >47250.857826</td>
#       <td id="T_129b8_row0_col1" class="data row0 col1" >64141.152369</td>
#       <td id="T_129b8_row0_col2" class="data row0 col2" >-16890.294542</td>
#       <td id="T_129b8_row0_col3" class="data row0 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row1" class="row_heading level0 row1" >Protein</th>
#       <td id="T_129b8_row1_col0" class="data row1 col0" >1616.843763</td>
#       <td id="T_129b8_row1_col1" class="data row1 col1" >1443.692190</td>
#       <td id="T_129b8_row1_col2" class="data row1 col2" >173.151574</td>
#       <td id="T_129b8_row1_col3" class="data row1 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row2" class="row_heading level0 row2" >Carbohydrate</th>
#       <td id="T_129b8_row2_col0" class="data row2 col0" >8134.677007</td>
#       <td id="T_129b8_row2_col1" class="data row2 col1" >4720.581306</td>
#       <td id="T_129b8_row2_col2" class="data row2 col2" >3414.095701</td>
#       <td id="T_129b8_row2_col3" class="data row2 col3" >Excessive</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row3" class="row_heading level0 row3" >Fiber</th>
#       <td id="T_129b8_row3_col0" class="data row3 col0" >217.967642</td>
#       <td id="T_129b8_row3_col1" class="data row3 col1" >897.976133</td>
#       <td id="T_129b8_row3_col2" class="data row3 col2" >-680.008492</td>
#       <td id="T_129b8_row3_col3" class="data row3 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row4" class="row_heading level0 row4" >Calcium</th>
#       <td id="T_129b8_row4_col0" class="data row4 col0" >5707.873058</td>
#       <td id="T_129b8_row4_col1" class="data row4 col1" >38257.405036</td>
#       <td id="T_129b8_row4_col2" class="data row4 col2" >-32549.531978</td>
#       <td id="T_129b8_row4_col3" class="data row4 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row5" class="row_heading level0 row5" >Phosphorus</th>
#       <td id="T_129b8_row5_col0" class="data row5 col0" >25727.294509</td>
#       <td id="T_129b8_row5_col1" class="data row5 col1" >28584.432778</td>
#       <td id="T_129b8_row5_col2" class="data row5 col2" >-2857.138270</td>
#       <td id="T_129b8_row5_col3" class="data row5 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row6" class="row_heading level0 row6" >Iron</th>
#       <td id="T_129b8_row6_col0" class="data row6 col0" >464.585228</td>
#       <td id="T_129b8_row6_col1" class="data row6 col1" >395.955015</td>
#       <td id="T_129b8_row6_col2" class="data row6 col2" >68.630213</td>
#       <td id="T_129b8_row6_col3" class="data row6 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row7" class="row_heading level0 row7" >Vitamin C</th>
#       <td id="T_129b8_row7_col0" class="data row7 col0" >156.240468</td>
#       <td id="T_129b8_row7_col1" class="data row7 col1" >2193.488690</td>
#       <td id="T_129b8_row7_col2" class="data row7 col2" >-2037.248221</td>
#       <td id="T_129b8_row7_col3" class="data row7 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row8" class="row_heading level0 row8" >Vitamin A</th>
#       <td id="T_129b8_row8_col0" class="data row8 col0" >3438.937565</td>
#       <td id="T_129b8_row8_col1" class="data row8 col1" >23997.242851</td>
#       <td id="T_129b8_row8_col2" class="data row8 col2" >-20558.305286</td>
#       <td id="T_129b8_row8_col3" class="data row8 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row9" class="row_heading level0 row9" >Potassium</th>
#       <td id="T_129b8_row9_col0" class="data row9 col0" >19047.912096</td>
#       <td id="T_129b8_row9_col1" class="data row9 col1" >158455.800256</td>
#       <td id="T_129b8_row9_col2" class="data row9 col2" >-139407.888160</td>
#       <td id="T_129b8_row9_col3" class="data row9 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row10" class="row_heading level0 row10" >Zinc</th>
#       <td id="T_129b8_row10_col0" class="data row10 col0" >104.001612</td>
#       <td id="T_129b8_row10_col1" class="data row10 col1" >290.228425</td>
#       <td id="T_129b8_row10_col2" class="data row10 col2" >-186.226813</td>
#       <td id="T_129b8_row10_col3" class="data row10 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row11" class="row_heading level0 row11" >Magnesium</th>
#       <td id="T_129b8_row11_col0" class="data row11 col0" >4966.890326</td>
#       <td id="T_129b8_row11_col1" class="data row11 col1" >10367.725992</td>
#       <td id="T_129b8_row11_col2" class="data row11 col2" >-5400.835667</td>
#       <td id="T_129b8_row11_col3" class="data row11 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_129b8_level0_row12" class="row_heading level0 row12" >Vitamin B-12</th>
#       <td id="T_129b8_row12_col0" class="data row12 col0" >40.223894</td>
#       <td id="T_129b8_row12_col1" class="data row12 col1" >72.204866</td>
#       <td id="T_129b8_row12_col2" class="data row12 col2" >-31.980971</td>
#       <td id="T_129b8_row12_col3" class="data row12 col3" >Satisfy</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*In the table above, a clear numerical juxtaposition between actual and recommended nutrient levels is evident, specifically tailored for households with more than one child. Notably, protein, carbohydrate, and iron exhibit excess quantities, while several other nutrients fall short of recommended levels. To guide our Food Stamp Policy effectively, we will prioritize targeting foods that are deficient in the most critical nutrients.*__
# * <span style = "color:#1FF30E">__*Furthermore, we apply the same methodology to identify nutrients that meet the recommended amounts. As evident, these include protein, fiber, iron, zinc, and vitamin B, aligning with the average household's nutritional profile.*__

# %% [markdown]
# <br>
#
# * ### *Through the construction of a table akin to the overall-household nutritional dataset above, with a focus on children's nutrient profiles, we aim to pinpoint the specific food item most lacking in essential nutrients for this demographic.*

# %%
# Normalize the nutrients columns
nutrients_insufficient = ["Energía", "Calcio", "Fosforo", "Vit. C", "Vit. A Equiv. Retinol", "Potasio", "Magnesio"]

# Make sure the nutrients_insufficient are used for normalization and calculation
fct_use = fct.copy()
fct_use[nutrients_insufficient] = fct_use[nutrients_insufficient].apply(lambda x: x / x.max())

# Calculate a Combined Score using the correct nutrient list
fct_use['Total_Score'] = fct_use[nutrients_insufficient].sum(axis=1)

# Sort the DataFrame by 'Total_Score' in descending order
sorted_fct = fct_use.sort_values(by='Total_Score', ascending=False)


# Initialize an empty list to store the names of the top five foods
top_five_foods = []

# Iterate through the first five rows and append the names to the list
for i, row in sorted_fct.head(6).iterrows():
    top_five_foods.append(row.name)

# Print the list of top five foods
print("Top five foods with the highest combined levels of nutrients:", top_five_foods)
# Out:
# Top five foods with the highest combined levels of nutrients: ['Condimentos', 'Leche En Polvo', 'Alimento Infantil', 'Picaritas', 'Frijoles', 'Porotos']

# %% [markdown]
# <br>
#
# * ### *Based on the findings presented, the top five foods exhibiting the highest cumulative nutrient levels are <span style = "color:green">Condiments, Milk Powder, Baby Food, Beans (Frijoles), and Beans (Porotos)</span>. You may have observed that there are two distinct types of beans commonly referred to as 'frijol' and 'poroto' in the Spanish-speaking world, each associated with specific regions. [According to Linguno](https://www.linguno.com/wordComparison/esp/frijol-judia-habichuela-poroto/), the usage of these terms can vary significantly depending on the country or locality. Given our objective of enhancing daily nutritional intake and focusing on food items within our "pbar" dataset, we have chosen to customize our food stamp policy specifically for<u><span style = "color:fuchsia"> __Beans(Porotos)__</span></u>.*
#
# <br>

# %%
# %matplotlib inline
use_Food_Stamp = 'Porotos'  # Good we want demand curve for

# Vary prices from 50% to 200% of reference.
scale = np.linspace(.5,2,20)

# Demand for Millet for household at median budget
plt.plot([result.demands(xref,my_prices(pbar[use_Food_Stamp]*s,pbar))[use_Food_Stamp] for s in scale],scale)

plt.ylabel(f"Price (relative to base of {pbar[use_Food_Stamp]:.2f})")
plt.xlabel(f"Quantities of Beans(Porotos) Demanded (lb)")
plt.title("Demand Curve (Marginal Benefit Curve) of Beans(Porotos)")
# Out:
# Text(0.5, 1.0, 'Demand Curve (Marginal Benefit Curve) of Beans(Porotos)')

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The demand curve for Beans(Porotos) exhibits a pronounced downward slope, resembling a nearly straight line. In terms of demand elasticity, it is notable that the quantity demanded shows a high level of responsiveness to changes in price. This characteristic underscores Beans(Porotos) as a prime candidate for our food stamp policy!*__
#
# <br>

# %%
# Reference budget
x0 = xbar.quantile(0.5)  # Household at 0.5 quantile is median

# %matplotlib inline

my_j = 'Porotos'  # Interesting Ugandan staple

P = np.geomspace(.01,10,50)*pbar[my_j]

# Utility of median household, given prices
U0 = result.indirect_utility(x0,pbar)

plt.plot([result.demands(x0,my_prices(p0,j=my_j),type="Marshallian")[my_j] for p0 in P],P)
plt.plot([result.demands(U0,my_prices(p0,j=my_j),type="Hicksian")[my_j] for p0 in P],P)
plt.ylabel('Price')
plt.grid(True)
plt.xlabel("Quantity Demanded (Marshallian, Income Fixed) & Utility (Hicksian)")
plt.legend(("Marshallian Curve","Hicksian Curve"))
plt.title("Marshallian Curve and Hicksian Curve for Beans(Porotos)")
# Out:
# Text(0.5, 1.0, 'Marshallian Curve and Hicksian Curve for Beans(Porotos)')

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The depicted figure presents two interrelated curves: the Marshallian Curve and the Hicksian Curve for Beans(Porotos). Surprisingly, they exhibit a concurrent trend.*__
# * <span style = "color:#1FF30E">__*The Marshallian demand curve illustrates the relationship between the price of a good and the quantity demanded, holding income constant, whereas the Hicksian demand curve is contingent upon prices and utility.*__
# * <span style = "color:#1FF30E">__*As the price approaches zero, consumer utility is maximized, leading to an increase in quantity demanded, while income remains fixed.*__
# <br>

# %% [markdown]
# ## 🚨🚨🚨 *__<span style = "color:#F3500E">Food (Beans-Porotos) Stamp Policy Interpretation:__*
#
#
# * ### *Our initiative to provide food stamps for households with more than one child aims to alleviate nutritional deficiencies by making Beans(Porotos) more accessible and affordable. The essence of this program lies in recognizing food stamps as a form of subsidy, effectively reducing the cost of Beans(Porotos) for eligible households. <u>By holding a Beans(Porotos) food stamp, families can purchase Beans(Porotos) at a discounted rate (price), directly lowering their expenditure on this essential nutrient-rich food item.*

# %% [markdown]
# * ### *This policy operates on the principle of decreasing the price of Beans(Porotos) exclusively for households with the designated food stamp. <u>Conversely, households without the food stamp will not benefit from this price reduction, thereby creating an incentive for eligible families to prioritize Beans(Porotos) in their meals.*

# %% [markdown]
# * ### *In practical terms, this strategy involves <u>collaborating with supermarket suppliers</u>to implement discounted pricing when households present their food stamps. The subsidy aspect comes into play through the utilization of tax revenue to compensate these suppliers for the discounted sales. <u>By effectively channeling tax revenue to cover the gap between the discounted price and the regular market price, we ensure that suppliers maintain their profit margins while simultaneously providing affordable Beans(Porotos) to targeted households.*

# %% [markdown]
# * ### *Crucially, <u>the total value of food stamps distributed equates to the overall decrease in Beans(Porotos) prices</u>, which aligns with the tax revenue allocated for supplier compensation. This equilibrium ensures that the subsidy provided through food stamps effectively translates into tangible benefits for eligible households, enabling them to afford and consume nutrient-rich Beans(Porotos) as a staple part of their diet.*
#
# <br>

# %% [markdown]
# ### *__<span style = "color:#F3500E">After multiple price adjustments for Porotos, we anticipate that a price decrease to 0.06 could significantly augment the insufficient supply while maintaining other nutrients within safe ranges. It's worth noting that the initial average price of this food is 0.7. Hence, we allocate a food stamp valued at 0.64 to households with more than one child.__*

# %%
prices_per_lb_food_stamp = prices_per_lb.copy()
prices_per_lb_food_stamp.loc["Porotos", 1997] = 0.06 # Change Price manually

qhat_food_stamp = xhat_unstack / prices_per_lb_food_stamp[1997]
qhat_food_stamp = qhat_food_stamp.loc[:, qhat_food_stamp.count() > 0]
use_food_stamp = fct.index.intersection(qhat_food_stamp.columns)
nutrients_food_stamp = qhat_food_stamp[use_food_stamp]@fct.loc[use_food_stamp, :]

nutrients_eng_food_stamp = nutrients_food_stamp.rename(columns = nutrient_translation)
use_nutrients_food_stamp = nutrients_eng_food_stamp.columns.intersection(hh_rwi.columns)
actual_nutrients_food_stamp = nutrients_eng_food_stamp[use_nutrients_food_stamp].mean()
whole_hh_food_stamp = comparision_table(actual_nutrients_food_stamp, recommended_nutrients)
whole_hh_food_stamp
# Out:
# <style type="text/css">
# #T_1abc6_row0_col3, #T_1abc6_row1_col3, #T_1abc6_row3_col3, #T_1abc6_row6_col3, #T_1abc6_row10_col3, #T_1abc6_row11_col3, #T_1abc6_row12_col3 {
#   background-color: lime;
# }
# #T_1abc6_row2_col3, #T_1abc6_row5_col3 {
#   background-color: red;
# }
# #T_1abc6_row4_col3, #T_1abc6_row7_col3, #T_1abc6_row8_col3, #T_1abc6_row9_col3 {
#   background-color: skyblue;
# }
# </style>
# <table id="T_1abc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1abc6_level0_col0" class="col_heading level0 col0" >Actual Nutrients</th>
#       <th id="T_1abc6_level0_col1" class="col_heading level0 col1" >Recommended Nutrients</th>
#       <th id="T_1abc6_level0_col2" class="col_heading level0 col2" >Difference</th>
#       <th id="T_1abc6_level0_col3" class="col_heading level0 col3" >Status</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >n</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1abc6_level0_row0" class="row_heading level0 row0" >Energy</th>
#       <td id="T_1abc6_row0_col0" class="data row0 col0" >52409.123142</td>
#       <td id="T_1abc6_row0_col1" class="data row0 col1" >51592.349608</td>
#       <td id="T_1abc6_row0_col2" class="data row0 col2" >816.773535</td>
#       <td id="T_1abc6_row0_col3" class="data row0 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row1" class="row_heading level0 row1" >Protein</th>
#       <td id="T_1abc6_row1_col0" class="data row1 col0" >2111.587089</td>
#       <td id="T_1abc6_row1_col1" class="data row1 col1" >1199.444202</td>
#       <td id="T_1abc6_row1_col2" class="data row1 col2" >912.142886</td>
#       <td id="T_1abc6_row1_col3" class="data row1 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row2" class="row_heading level0 row2" >Carbohydrate</th>
#       <td id="T_1abc6_row2_col0" class="data row2 col0" >9073.347312</td>
#       <td id="T_1abc6_row2_col1" class="data row2 col1" >3716.312663</td>
#       <td id="T_1abc6_row2_col2" class="data row2 col2" >5357.034648</td>
#       <td id="T_1abc6_row2_col3" class="data row2 col3" >Excessive</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row3" class="row_heading level0 row3" >Fiber</th>
#       <td id="T_1abc6_row3_col0" class="data row3 col0" >621.333836</td>
#       <td id="T_1abc6_row3_col1" class="data row3 col1" >722.292895</td>
#       <td id="T_1abc6_row3_col2" class="data row3 col2" >-100.959059</td>
#       <td id="T_1abc6_row3_col3" class="data row3 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row4" class="row_heading level0 row4" >Calcium</th>
#       <td id="T_1abc6_row4_col0" class="data row4 col0" >7536.623541</td>
#       <td id="T_1abc6_row4_col1" class="data row4 col1" >30124.754795</td>
#       <td id="T_1abc6_row4_col2" class="data row4 col2" >-22588.131254</td>
#       <td id="T_1abc6_row4_col3" class="data row4 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row5" class="row_heading level0 row5" >Phosphorus</th>
#       <td id="T_1abc6_row5_col0" class="data row5 col0" >34734.547621</td>
#       <td id="T_1abc6_row5_col1" class="data row5 col1" >22095.653335</td>
#       <td id="T_1abc6_row5_col2" class="data row5 col2" >12638.894287</td>
#       <td id="T_1abc6_row5_col3" class="data row5 col3" >Excessive</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row6" class="row_heading level0 row6" >Iron</th>
#       <td id="T_1abc6_row6_col0" class="data row6 col0" >610.742358</td>
#       <td id="T_1abc6_row6_col1" class="data row6 col1" >307.683032</td>
#       <td id="T_1abc6_row6_col2" class="data row6 col2" >303.059326</td>
#       <td id="T_1abc6_row6_col3" class="data row6 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row7" class="row_heading level0 row7" >Vitamin C</th>
#       <td id="T_1abc6_row7_col0" class="data row7 col0" >285.104479</td>
#       <td id="T_1abc6_row7_col1" class="data row7 col1" >1848.361214</td>
#       <td id="T_1abc6_row7_col2" class="data row7 col2" >-1563.256735</td>
#       <td id="T_1abc6_row7_col3" class="data row7 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row8" class="row_heading level0 row8" >Vitamin A</th>
#       <td id="T_1abc6_row8_col0" class="data row8 col0" >3213.056676</td>
#       <td id="T_1abc6_row8_col1" class="data row8 col1" >19691.886443</td>
#       <td id="T_1abc6_row8_col2" class="data row8 col2" >-16478.829767</td>
#       <td id="T_1abc6_row8_col3" class="data row8 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row9" class="row_heading level0 row9" >Potassium</th>
#       <td id="T_1abc6_row9_col0" class="data row9 col0" >55273.501860</td>
#       <td id="T_1abc6_row9_col1" class="data row9 col1" >126563.867698</td>
#       <td id="T_1abc6_row9_col2" class="data row9 col2" >-71290.365839</td>
#       <td id="T_1abc6_row9_col3" class="data row9 col3" >Insufficient</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row10" class="row_heading level0 row10" >Zinc</th>
#       <td id="T_1abc6_row10_col0" class="data row10 col0" >172.432911</td>
#       <td id="T_1abc6_row10_col1" class="data row10 col1" >237.394671</td>
#       <td id="T_1abc6_row10_col2" class="data row10 col2" >-64.961760</td>
#       <td id="T_1abc6_row10_col3" class="data row10 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row11" class="row_heading level0 row11" >Magnesium</th>
#       <td id="T_1abc6_row11_col0" class="data row11 col0" >8296.473159</td>
#       <td id="T_1abc6_row11_col1" class="data row11 col1" >8623.544573</td>
#       <td id="T_1abc6_row11_col2" class="data row11 col2" >-327.071414</td>
#       <td id="T_1abc6_row11_col3" class="data row11 col3" >Satisfy</td>
#     </tr>
#     <tr>
#       <th id="T_1abc6_level0_row12" class="row_heading level0 row12" >Vitamin B-12</th>
#       <td id="T_1abc6_row12_col0" class="data row12 col0" >37.846714</td>
#       <td id="T_1abc6_row12_col1" class="data row12 col1" >59.069137</td>
#       <td id="T_1abc6_row12_col2" class="data row12 col2" >-21.222422</td>
#       <td id="T_1abc6_row12_col3" class="data row12 col3" >Satisfy</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*Following the implementation of the Food Stamp Policy, with a par value of $0.06, for beans (Porotos), it is evident from the data provided in the table that the levels of Energy and Magnesium, previously categorized as insufficient, have now improved to satisfy the required nutritional standards. This change underscores the effectiveness of the food stamp initiative in enhancing the dietary quality of households that benefit from it!*__

# %%
# Visualization
df_food_stamp = whole_hh_food_stamp.data

bar_width = 0.35

# Generate an array of indices for the x-axis
indices = np.arange(len(df_original))

# Plot the difference for the first styled DataFrame
plt.bar(indices, df_original['Difference'], bar_width, color='b', label='Before Food Stamp')

# Plot the difference for the second styled DataFrame
plt.bar(indices + bar_width, df_food_stamp['Difference'], bar_width, color='r', label='After Food Stamp')

plt.xlabel('Nutrients')
plt.ylabel('Difference')
plt.title('Nutrient Amount Before and After Food Stamp Policy(par value = 0.64) on Beans(Porotos)')
plt.xticks(indices + bar_width / 2, df_original.index, rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# ### *__<span style = "color:#1FF30E">Interpretation:__*
# * <span style = "color:#1FF30E">__*The graph provided offers a clear visualization of the nutrient levels in beans (Porotos) before and after the implementation of the Food Stamp Policy. This visual aid highlights improvements in previously insufficient nutrients, such as Vitamin A, Calcium, and Energy.*__
# * <span style = "color:#1FF30E">__*While it is noted that some nutrients, like Phosphorus, have shifted from insufficient to excessive levels, the overall impact remains within acceptable ranges.*__
# * <span style = "color:#f44336">__*This graphical representation underscores the policy's effectiveness in enhancing nutritional intake, thereby supporting healthier dietary outcomes for the targeted populations.*__

# %% [markdown]
# <br>
#
#
# ## __[C] Policy Cost__

# %% [markdown]
# ### 💰📝 *__<span style = "color:#F3500E">Policy Cost Analystics [I]- Food (Beans-Porotos) Stamp Policy__*

# %%
def compensating_variation(U0,p0,p1):
    x0 = result.expenditure(U0,p0)
    x1 = result.expenditure(U0,p1)
    return x1-x0

def revenue(U0,p0,p1,type='Marshallian'):
    """(Un)Compensated revenue from taxes changing vector of prices from p0 to p1.
    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """    
    dp = p1 - p0 # Change in prices
    c = result.demands(U0,p1,type=type)
    dp,c = dp.align(c,join='inner')
    return dp.T@c

def deadweight_loss(U0,p0,p1):
    """
    Deadweight loss of tax/subsidy scheme creating wedge in prices from p0 to p1.
    Note that this is only for *demand* side (i.e., if supply perfectly elastic).
    """
    cv = compensating_variation(U0,p0,p1)
    return cv - revenue(U0,p0,p1,type='Hicksian')

# Find index where price is closest to 0.06
idx = np.abs(np.array(P) - 0.06).argmin()

# Get corresponding y-value
y_value = deadweight_loss(U0, pbar, my_prices(P[idx], j=my_j))  # DWL

fig, ax1 = plt.subplots()

# Plot the deadweight loss curve
ax1.plot(P, [deadweight_loss(U0, pbar, my_prices(p0, j=my_j)) for p0 in P])

ax1.scatter(0.06, y_value, color='lime')
ax1.annotate('Stamp Policy Point (0.06, 1.17)', xy=(0.3, 1.17), xytext=(2.0, 1.10),
             arrowprops=dict(facecolor='black', shrink=0.001))

ax1.set_xlabel("Price of %s" % my_j)
ax1.set_ylabel("Deadweight Loss")
ax1.set_title("Deadweight Loss in Beans (Porotos)")

plt.show()

# %%
print("Deadweight loss of Food Stamp Policy on Beans(Porotos) with par value of 0.06:", y_value)
# Out:
# Deadweight loss of Food Stamp Policy on Beans(Porotos) with par value of 0.06: 1.1713964025046035

# %% [markdown]
# <br>
#
# ### 💰📝 *__<span style = "color:#F3500E">Policy Cost Analystics [II]- Lentejas(lentils) Taxation Policy__*

# %%
idx_tax = np.abs(np.array(P_tax) - new_price).argmin()

# Get corresponding y-value
y_value_tax = deadweight_loss(U0, pbar, my_prices(P_tax[idx_tax], j=my_j_tax))  # DWL

fig, ax1 = plt.subplots()

# Plot the deadweight loss curve
ax1.plot(P_tax, [deadweight_loss(U0, pbar, my_prices(p0, j=my_j_tax)) for p0 in P_tax])

ax1.scatter(new_price, y_value_tax, color='lime')
ax1.annotate('Taxation Policy Point (0.06, 1.17)', xy=(1.50, 0.18), xytext=(1.0, 1.6),
             arrowprops=dict(facecolor='black', shrink=0.001))

ax1.set_xlabel("Price of %s" % my_j_tax)
ax1.set_ylabel("Deadweight Loss")
ax1.set_title("Deadweight Loss in Lentejas(lentils)")

plt.show()

# %%
print("Deadweight loss of Taxation Policy on Lentejas (lentils) with 50% (price increase amount: {:.3f}) price increases: {}".format(new_price-original_price, y_value_tax))
# Out:
# Deadweight loss of Taxation Policy on Lentejas (lentils) with 50% (price increase amount: 0.496) price increases: 0.04390625315677765

# %% [markdown]
# <br>
#
# ### 💰📝 *__<span style = "color:#F3500E">Policy Cost Analystics [III]- Total DWL of Our Two Policies:__*

# %%
sum_value = y_value+y_value_tax
print("Total Dead Weight Loss of Our Two Polic:", sum_value)
# Out:
# Total Dead Weight Loss of Our Two Polic: 1.215302655661381

# %% [markdown]
# <br>
#
# ### __<div style="text-align: right"> <span style="font-family:Papyrus; ">-------------------------- The End.</span></div>__
